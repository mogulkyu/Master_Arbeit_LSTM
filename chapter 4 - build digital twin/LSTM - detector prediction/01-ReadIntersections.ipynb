# %% [markdown]
# **Import intersection definition from mycity**
#
# In the folder intersections there are files from Landau intersections

# %%
folder = 'input/intersections'

# %%
import os
import json

def find_json_files(directory):
    files = []
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        files.append(filepath)
    return files

# %%
json_files = find_json_files(folder)

# %% [markdown]
# **Interpret Contents of the files**

# %% [markdown]
# **Parse first file and understand the content**

# %%
import json
from collections import defaultdict

for file in json_files:

    with open(file, 'r') as f:  
        json_data = json.load(f)  

    # Extract the intersection name
    intersection_name = json_data["tlc"]["name"]

    if intersection_name == 'LD-LSA1':
    
        # Extract the detector IDs
        detector_ids = []
        print(f"### Intersection Name: {intersection_name}")

        for sw_status in json_data.get("tlc", {}).get("softwareStatus", []):
            node = sw_status.get("node", {})
            detectors = node.get("detectors", [])

            for d in detectors:
                print(
                    f"Detector ID={d['id']}, "
                    f"Name={d['name']}, "
                    f"Type={d['detectorType']}"
                )
# Out:
# ### Intersection Name: LD-LSA1
# Detector ID=7, Name=DET11, Type=NONE
# Detector ID=8, Name=DET12, Type=NONE
# Detector ID=9, Name=DET21, Type=NONE
# Detector ID=10, Name=DET22, Type=NONE
# Detector ID=11, Name=DET31, Type=NONE
# Detector ID=12, Name=DET32, Type=NONE
# Detector ID=13, Name=DET41, Type=NONE
# Detector ID=14, Name=DET42, Type=NONE
# Detector ID=15, Name=TAS1, Type=NONE
# Detector ID=16, Name=TAS1a, Type=NONE
# Detector ID=17, Name=TAS2, Type=NONE
# Detector ID=18, Name=TAS2a, Type=NONE
# Detector ID=19, Name=TAS3, Type=NONE
# Detector ID=20, Name=TAS3a, Type=NONE
# Detector ID=21, Name=TAS4, Type=NONE
# Detector ID=22, Name=TAS4a, Type=NONE
# Detector ID=23, Name=DET43, Type=NONE
# Detector ID=24, Name=DET44, Type=NONE
# Detector ID=25, Name=DET51, Type=NONE
# Detector ID=26, Name=DET52, Type=NONE
# Detector ID=27, Name=DET61, Type=NONE
# Detector ID=28, Name=DET71, Type=NONE
# Detector ID=29, Name=DET72, Type=NONE
# Detector ID=30, Name=DET73, Type=NONE
# Detector ID=31, Name=TAS5, Type=NONE
# Detector ID=32, Name=TAS5a, Type=NONE
# Detector ID=33, Name=TAS6, Type=NONE
# Detector ID=34, Name=TAS6a, Type=NONE
# Detector ID=35, Name=BTAS1, Type=NONE
# Detector ID=36, Name=BTAS1a, Type=NONE
# Detector ID=37, Name=BTAS2, Type=NONE
# Detector ID=38, Name=BTAS2a, Type=NONE
# Detector ID=39, Name=DET74, Type=NONE
# Detector ID=40, Name=DET81, Type=NONE
# Detector ID=41, Name=BTAS3, Type=NONE
# Detector ID=42, Name=BTAS3a, Type=NONE
# Detector ID=43, Name=BTAS4, Type=NONE
# Detector ID=44, Name=BTAS4a, Type=NONE
# Detector ID=45, Name=BTAS5, Type=NONE
# Detector ID=46, Name=BTAS5a, Type=NONE
# Detector ID=47, Name=BTAS6, Type=NONE
# Detector ID=48, Name=BTAS6a, Type=NONE

# %% [markdown]
# **Check state before using AI**

# %%
import json

def check_state(tlc: dict):
    reasons = []

    # 1) Active?
    if tlc.get("active") is False:
        reasons.append("active=False")

    # 2) General State?
    state = tlc.get("state")
    if state is not None and state != "NO_FAILURE":
        reasons.append(f"state={state} (expected NO_FAILURE)")

    # 3) Is there any fault dedector producing same value or always give 0?
    broken = tlc.get("brokenDetectorCount")
    if isinstance(broken, int) and broken > 0:
        reasons.append(f"brokenDetectorCount={broken}")

    # 4) Checking the hardware status
    hw = tlc.get("hardwareStatus", {})
    if isinstance(hw, dict):
        if hw.get("powerOk") is False:
            reasons.append("hardwareStatus.powerOk=False")
        if hw.get("emergencyOff") is True:
            reasons.append("hardwareStatus.emergencyOff=True")
        if hw.get("doorOpen") is True:
            reasons.append("hardwareStatus.doorOpen=True")
        if hw.get("persistenceOk") is False:
            reasons.append("hardwareStatus.persistenceOk=False")

    # 5) Reading Flags?
    if tlc.get("readDetectors") is False:
        reasons.append("readDetectors=False")

    ok = (len(reasons) == 0)
    return ok, reasons


#  Run state check for LD-LSA1
for file in json_files:
    with open(file, "r", encoding="utf-8") as f:
        json_data = json.load(f)

    tlc = json_data.get("tlc", {})
    intersection_name = tlc.get("name")

    if intersection_name == "LD-LSA1":
        ok, reasons = check_state(tlc)

        print(f"### STATE CHECK: {intersection_name}")
        if ok:
            print("OK -> AI/analysis can proceed")
        else:
            print("NOT OK -> do NOT use AI on this snapshot")
            for r in reasons:
                print(" -", r)

        # Summary 
        print("Summary:",
              "state=", tlc.get("state"),
              "| active=", tlc.get("active"),
              "| brokenDetectorCount=", tlc.get("brokenDetectorCount"),
              "| powerOk=", tlc.get("hardwareStatus", {}).get("powerOk"),
              "| emergencyOff=", tlc.get("hardwareStatus", {}).get("emergencyOff"))
        break
# Out:
# ### STATE CHECK: LD-LSA1
# NOT OK -> do NOT use AI on this snapshot
#  - state=INTERNAL_FAILURE (expected NO_FAILURE)
#  - brokenDetectorCount=2
# Summary: state= INTERNAL_FAILURE | active= True | brokenDetectorCount= 2 | powerOk= True | emergencyOff= False

# %% [markdown]
# **Which dedectors have failure?**

# %%
for file in json_files:
    with open(file, "r", encoding="utf-8") as f:
        j = json.load(f)
#which dedectors have failure?
    tlc = j.get("tlc", {})
    if tlc.get("name") == "LD-LSA1":
        hw = tlc.get("hardwareStatus", {})
        print("faultDetectors:", hw.get("faultDetectors"))
        break
# Out:
# faultDetectors: [{'detectorType': 'NONE', 'id': '29', 'name': 'DET72'}, {'detectorType': 'NONE', 'id': '25', 'name': 'DET51'}]

# %% [markdown]
# **Trying to apply the same code for all intersections :**

# %% [markdown]
# **My corridor LSA: LD-LSA16 LD-LSA10 LD-LSA8 LD-LSA24 LD-LSA29 LD-LSA32 LD-LSA3 LD-LSA11 LD-LSA5 LD-LSA4 LD-LSA40 LD-LSA42 LD-LSA1**

# %%
import os
import json

folder = r"C:\Users\mogul\OneDrive\Masaüstü\mt_emre\chapter 4 - build digital twin\LSTM - detector prediction\input\intersections"

def find_json_files(directory):
    files = []
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        if os.path.isfile(filepath) and filename.lower().endswith(".json"):
            files.append(filepath)
    return files

json_files = find_json_files(folder)

important_intersections = {
    "LD-LSA16", "LD-LSA10", "LD-LSA8", "LD-LSA24", "LD-LSA29", "LD-LSA32",
    "LD-LSA3", "LD-LSA11", "LD-LSA5", "LD-LSA4", "LD-LSA40", "LD-LSA42", "LD-LSA1"
}

found_intersections = []   # <-- buraya toplayacağız

for file in json_files:
    with open(file, "r", encoding="utf-8") as f:
        json_data = json.load(f)

    tlc = json_data.get("tlc", {})
    alias = tlc.get("alias", "")
    name = tlc.get("name", "")

    if alias in important_intersections:
        found_intersections.append(alias)

        print(f"\n### Intersection Name: {alias}")
        print(f"Full name: {name}")

        for sw_status in tlc.get("softwareStatus", []):
            node = sw_status.get("node", {})
            detectors = node.get("detectors", [])

            for d in detectors:
                print(
                    f"Detector ID={d.get('id')}, "
                    f"Name={d.get('name')}, "
                    f"Type={d.get('detectorType')}"
                )

# 🔽 EN SON: intersection ID'lerini tek satırda yazdır
print("\n=== INTERSECTIONS IN CORRIDOR ===")
print(", ".join(sorted(found_intersections)))
# Out:
# ### Intersection Name: LD-LSA29
# Full name: LD-LSA29 (Ostring/Industriestr.)
# Detector ID=1, Name=D1, Type=NONE
# Detector ID=2, Name=D1a, Type=NONE
# Detector ID=3, Name=D2, Type=NONE
# Detector ID=4, Name=D2a, Type=NONE
# Detector ID=5, Name=D2b, Type=NONE
# Detector ID=6, Name=D2c, Type=NONE
# Detector ID=7, Name=D2d, Type=NONE
# Detector ID=8, Name=D2e, Type=NONE
# Detector ID=9, Name=D3, Type=NONE
# Detector ID=10, Name=D3a, Type=NONE
# Detector ID=11, Name=D4, Type=NONE
# Detector ID=12, Name=D4a, Type=NONE
# Detector ID=13, Name=D4b, Type=NONE
# Detector ID=14, Name=T1, Type=NONE
# Detector ID=15, Name=T3, Type=NONE
# Detector ID=16, Name=BT1, Type=NONE
# Detector ID=17, Name=BT2, Type=NONE
# Detector ID=18, Name=BT3, Type=NONE
# Detector ID=19, Name=BT4, Type=NONE
# Detector ID=20, Name=FEan, Type=NONE
# Detector ID=21, Name=FEab, Type=NONE
# Detector ID=22, Name=VKx_iO, Type=NONE
# Detector ID=23, Name=WK1_Error, Type=NONE
# Detector ID=24, Name=WK3_Error, Type=NONE
# Detector ID=25, Name=WK5_Error, Type=NONE
# Detector ID=26, Name=WK7_Error, Type=NONE
#
# ### Intersection Name: LD-LSA3
# Full name: LD-LSA3
# Detector ID=1, Name=IS2_WBK1, Type=NONE
# Detector ID=2, Name=IS6_WBK2, Type=NONE
# Detector ID=3, Name=CAM_Ln9_50m, Type=NONE
# Detector ID=4, Name=CAM_Ln9_150m, Type=NONE
# Detector ID=5, Name=CAM_Ln9_300m, Type=NONE
# Detector ID=6, Name=CAM_Ln9_415m, Type=NONE
# Detector ID=7, Name=CAM_Ln6_50m, Type=NONE
# Detector ID=8, Name=CAM_Ln6_135m, Type=NONE
# Detector ID=9, Name=CAM_Ln7, Type=NONE
# Detector ID=10, Name=FW, Type=NONE
# Detector ID=11, Name=WBK1_Err, Type=NONE
# Detector ID=12, Name=WBK2_Err, Type=NONE
# Detector ID=13, Name=CAM_Ln8, Type=NONE
#
# ### Intersection Name: LD-LSA5
# Full name: LD-LSA5
# Detector ID=1, Name=D1_2, Type=NONE
# Detector ID=2, Name=D2_1, Type=NONE
# Detector ID=3, Name=D2_2, Type=NONE
# Detector ID=4, Name=D3_2, Type=NONE
# Detector ID=5, Name=D4_1_VK4, Type=NONE
# Detector ID=6, Name=D4_2_VK4, Type=NONE
# Detector ID=7, Name=D5_1_VK5, Type=NONE
# Detector ID=8, Name=D5_2_VK5, Type=NONE
# Detector ID=9, Name=D6_2, Type=NONE
# Detector ID=10, Name=D7_1_WBK2, Type=NONE
# Detector ID=11, Name=D8_2, Type=NONE
# Detector ID=12, Name=D8_4, Type=NONE
# Detector ID=13, Name=D9_1_WBK1, Type=NONE
# Detector ID=14, Name=T1s_T2s, Type=NONE
# Detector ID=15, Name=T1b_T2b, Type=NONE
# Detector ID=16, Name=T3s_T4s, Type=NONE
# Detector ID=17, Name=T3b_T4b, Type=NONE
# Detector ID=18, Name=T5s_T6s, Type=NONE
# Detector ID=19, Name=T5b_T6b, Type=NONE
# Detector ID=20, Name=T82s_T9s, Type=NONE
# Detector ID=21, Name=T82b_T9b, Type=NONE
# Detector ID=22, Name=T10s_T11s, Type=NONE
# Detector ID=23, Name=T10b_T11b, Type=NONE
# Detector ID=24, Name=T7b_T81b, Type=NONE
# Detector ID=25, Name=VK_i_O_, Type=NONE
# Detector ID=26, Name=WBK1_Err, Type=NONE
# Detector ID=27, Name=WBK2_Err, Type=NONE
#
# ### Intersection Name: LD-LSA16
# Full name: LD-LSA16
# Detector ID=1, Name=VD11, Type=NONE
# Detector ID=2, Name=VD12, Type=NONE
# Detector ID=3, Name=WD21, Type=NONE
# Detector ID=4, Name=WD22, Type=NONE
# Detector ID=5, Name=VD23, Type=NONE
# Detector ID=6, Name=VD31, Type=NONE
# Detector ID=7, Name=VD32, Type=NONE
# Detector ID=8, Name=WD41, Type=NONE
# Detector ID=9, Name=WD42, Type=NONE
# Detector ID=10, Name=VD43, Type=NONE
# Detector ID=11, Name=VD44, Type=NONE
# Detector ID=12, Name=D24, Type=NONE
# Detector ID=13, Name=D25, Type=NONE
# Detector ID=14, Name=D45, Type=NONE
# Detector ID=15, Name=D46, Type=NONE
# Detector ID=16, Name=DK1_s, Type=NONE
# Detector ID=17, Name=DK3_s, Type=NONE
# Detector ID=18, Name=DK1_b, Type=NONE
# Detector ID=19, Name=DK2_b, Type=NONE
# Detector ID=20, Name=DK3_b, Type=NONE
# Detector ID=21, Name=DK4_b, Type=NONE
# Detector ID=22, Name=WBK1_Err, Type=NONE
# Detector ID=23, Name=WBK2_Err, Type=NONE
# Detector ID=24, Name=VK14_i_O, Type=NONE
# Detector ID=25, Name=PA, Type=NONE
# Detector ID=26, Name=PB, Type=NONE
# Detector ID=27, Name=PC, Type=NONE
# Detector ID=28, Name=GB, Type=NONE
# Detector ID=29, Name=FR, Type=NONE
# Detector ID=30, Name=Sy1, Type=NONE
# Detector ID=31, Name=DK5_s, Type=NONE
# Detector ID=32, Name=DK5_b, Type=NONE
# Detector ID=33, Name=VD13, Type=NONE
#
# ### Intersection Name: LD-LSA10
# Full name: LD-LSA10
# Detector ID=1, Name=VD11, Type=NONE
# Detector ID=2, Name=VD25, Type=NONE
# Detector ID=3, Name=VD41, Type=NONE
# Detector ID=4, Name=VD42, Type=NONE
# Detector ID=5, Name=D25, Type=NONE
# Detector ID=6, Name=T1s, Type=NONE
# Detector ID=7, Name=T2s, Type=NONE
# Detector ID=8, Name=T3s, Type=NONE
# Detector ID=9, Name=T4s, Type=NONE
# Detector ID=10, Name=T7s, Type=NONE
# Detector ID=11, Name=T8s, Type=NONE
# Detector ID=12, Name=T9s, Type=NONE
# Detector ID=13, Name=T1b, Type=NONE
# Detector ID=14, Name=T2b, Type=NONE
# Detector ID=15, Name=T3b, Type=NONE
# Detector ID=16, Name=T4b, Type=NONE
# Detector ID=17, Name=T5b, Type=NONE
# Detector ID=18, Name=T6b, Type=NONE
# Detector ID=19, Name=T7b, Type=NONE
# Detector ID=20, Name=T8b, Type=NONE
# Detector ID=21, Name=T9b, Type=NONE
# Detector ID=22, Name=T10b, Type=NONE
# Detector ID=23, Name=T11b, Type=NONE
# Detector ID=24, Name=WD21, Type=NONE
# Detector ID=25, Name=WD22, Type=NONE
# Detector ID=26, Name=WD23, Type=NONE
# Detector ID=27, Name=WD24, Type=NONE
# Detector ID=28, Name=WD31, Type=NONE
# Detector ID=29, Name=WD32, Type=NONE
# Detector ID=30, Name=WD51, Type=NONE
# Detector ID=31, Name=WD52, Type=NONE
# Detector ID=32, Name=PA, Type=NONE
# Detector ID=33, Name=PB, Type=NONE
# Detector ID=34, Name=PC, Type=NONE
# Detector ID=35, Name=GB, Type=NONE
# Detector ID=36, Name=FR, Type=NONE
# Detector ID=37, Name=SY1, Type=NONE
# Detector ID=38, Name=WBK1_Err, Type=NONE
# Detector ID=39, Name=WBK2_Err, Type=NONE
# Detector ID=40, Name=WBK3_Err, Type=NONE
# Detector ID=41, Name=VKx_iO, Type=NONE
#
# ### Intersection Name: LD-LSA42
# Full name: LD-LSA42 (L509/In den Grabengärten)
# Detector ID=1, Name=D1, Type=NONE
# Detector ID=2, Name=D2, Type=NONE
# Detector ID=3, Name=D3, Type=NONE
# Detector ID=4, Name=D4, Type=NONE
# Detector ID=5, Name=D5, Type=NONE
# Detector ID=6, Name=D6, Type=NONE
# Detector ID=7, Name=D7, Type=NONE
# Detector ID=8, Name=D8, Type=NONE
# Detector ID=9, Name=D9, Type=NONE
# Detector ID=10, Name=D10, Type=NONE
# Detector ID=11, Name=D11, Type=NONE
# Detector ID=12, Name=T2, Type=NONE
# Detector ID=13, Name=T3, Type=NONE
# Detector ID=14, Name=T4, Type=NONE
# Detector ID=15, Name=T51, Type=NONE
# Detector ID=16, Name=T52, Type=NONE
#
# ### Intersection Name: LD-LSA40
# Full name: LD-LSA40 (L509 Queichheimer Brücke)
# Detector ID=1, Name=T1_3s, Type=NONE
#
# ### Intersection Name: LD-LSA11
# Full name: LD-LSA11 (Maximilian-/Dammühlstr.)
# Detector ID=1, Name=D1, Type=NONE
# Detector ID=2, Name=D2, Type=NONE
# Detector ID=3, Name=FT2, Type=NONE
# Detector ID=4, Name=FT2a, Type=NONE
#
# ### Intersection Name: LD-LSA24
# Full name: LD-LSA24 (Ostring/Martin-Luther-Str.)
# Detector ID=1, Name=D1, Type=NONE
# Detector ID=2, Name=D6b, Type=NONE
# Detector ID=3, Name=D2, Type=NONE
# Detector ID=4, Name=D2a, Type=NONE
# Detector ID=5, Name=D3, Type=NONE
# Detector ID=6, Name=D3a, Type=NONE
# Detector ID=7, Name=T1, Type=NONE
# Detector ID=8, Name=T3, Type=NONE
# Detector ID=9, Name=BT1, Type=NONE
# Detector ID=10, Name=BT2, Type=NONE
# Detector ID=11, Name=BT3, Type=NONE
# Detector ID=12, Name=D3b, Type=NONE
# Detector ID=13, Name=VKx_iO, Type=NONE
# Detector ID=14, Name=WK1_Error, Type=NONE
# Detector ID=15, Name=WK3_Error, Type=NONE
# Detector ID=16, Name=D4, Type=NONE
# Detector ID=17, Name=BT4, Type=NONE
# Detector ID=18, Name=FEan, Type=NONE
# Detector ID=19, Name=FEab, Type=NONE
# Detector ID=20, Name=D5, Type=NONE
# Detector ID=21, Name=D5a, Type=NONE
# Detector ID=22, Name=D6, Type=NONE
# Detector ID=23, Name=D6a, Type=NONE
# Detector ID=24, Name=WK5_Error, Type=NONE
# Detector ID=25, Name=WK7_Error, Type=NONE
#
# ### Intersection Name: LD-LSA32
# Full name: LD-LSA32 (Nordring/Haardtstr.)
# Detector ID=1, Name=D1, Type=NONE
# Detector ID=2, Name=D1a, Type=NONE
# Detector ID=3, Name=D1b, Type=NONE
# Detector ID=4, Name=D2, Type=NONE
# Detector ID=5, Name=D3, Type=NONE
# Detector ID=6, Name=D3a, Type=NONE
# Detector ID=7, Name=T2, Type=NONE
# Detector ID=8, Name=T4, Type=NONE
# Detector ID=9, Name=BT1, Type=NONE
# Detector ID=10, Name=BT2, Type=NONE
# Detector ID=11, Name=BT3, Type=NONE
# Detector ID=12, Name=D3b, Type=NONE
# Detector ID=13, Name=D3c, Type=NONE
# Detector ID=14, Name=D4, Type=NONE
# Detector ID=15, Name=D4a, Type=NONE
# Detector ID=16, Name=D4b, Type=NONE
# Detector ID=17, Name=BT4, Type=NONE
# Detector ID=18, Name=FEan, Type=NONE
# Detector ID=19, Name=FEab, Type=NONE
# Detector ID=20, Name=VKx_iO, Type=NONE
# Detector ID=21, Name=WK1_Error, Type=NONE
# Detector ID=22, Name=WK3_Error, Type=NONE
# Detector ID=23, Name=WK4_Error, Type=NONE
#
# ### Intersection Name: LD-LSA1
# Full name: LD-LSA1
# Detector ID=7, Name=DET11, Type=NONE
# Detector ID=8, Name=DET12, Type=NONE
# Detector ID=9, Name=DET21, Type=NONE
# Detector ID=10, Name=DET22, Type=NONE
# Detector ID=11, Name=DET31, Type=NONE
# Detector ID=12, Name=DET32, Type=NONE
# Detector ID=13, Name=DET41, Type=NONE
# Detector ID=14, Name=DET42, Type=NONE
# Detector ID=15, Name=TAS1, Type=NONE
# Detector ID=16, Name=TAS1a, Type=NONE
# Detector ID=17, Name=TAS2, Type=NONE
# Detector ID=18, Name=TAS2a, Type=NONE
# Detector ID=19, Name=TAS3, Type=NONE
# Detector ID=20, Name=TAS3a, Type=NONE
# Detector ID=21, Name=TAS4, Type=NONE
# Detector ID=22, Name=TAS4a, Type=NONE
# Detector ID=23, Name=DET43, Type=NONE
# Detector ID=24, Name=DET44, Type=NONE
# Detector ID=25, Name=DET51, Type=NONE
# Detector ID=26, Name=DET52, Type=NONE
# Detector ID=27, Name=DET61, Type=NONE
# Detector ID=28, Name=DET71, Type=NONE
# Detector ID=29, Name=DET72, Type=NONE
# Detector ID=30, Name=DET73, Type=NONE
# Detector ID=31, Name=TAS5, Type=NONE
# Detector ID=32, Name=TAS5a, Type=NONE
# Detector ID=33, Name=TAS6, Type=NONE
# Detector ID=34, Name=TAS6a, Type=NONE
# Detector ID=35, Name=BTAS1, Type=NONE
# Detector ID=36, Name=BTAS1a, Type=NONE
# Detector ID=37, Name=BTAS2, Type=NONE
# Detector ID=38, Name=BTAS2a, Type=NONE
# Detector ID=39, Name=DET74, Type=NONE
# Detector ID=40, Name=DET81, Type=NONE
# Detector ID=41, Name=BTAS3, Type=NONE
# Detector ID=42, Name=BTAS3a, Type=NONE
# Detector ID=43, Name=BTAS4, Type=NONE
# Detector ID=44, Name=BTAS4a, Type=NONE
# Detector ID=45, Name=BTAS5, Type=NONE
# Detector ID=46, Name=BTAS5a, Type=NONE
# Detector ID=47, Name=BTAS6, Type=NONE
# Detector ID=48, Name=BTAS6a, Type=NONE
#
# ### Intersection Name: LD-LSA8
# Full name: LD-LSA8
# Detector ID=1, Name=D2_1, Type=NONE
# Detector ID=2, Name=D2_3, Type=NONE
# Detector ID=3, Name=D4_1, Type=NONE
# Detector ID=4, Name=D5_1, Type=NONE
# Detector ID=5, Name=D6_1, Type=NONE
# Detector ID=6, Name=T1s, Type=NONE
# Detector ID=7, Name=T1b, Type=NONE
# Detector ID=8, Name=T2s, Type=NONE
# Detector ID=9, Name=T2b, Type=NONE
# Detector ID=10, Name=T3s, Type=NONE
# Detector ID=11, Name=T3b, Type=NONE
# Detector ID=12, Name=T4b, Type=NONE
# Detector ID=13, Name=T5b, Type=NONE
# Detector ID=14, Name=T6s, Type=NONE
# Detector ID=15, Name=T6b, Type=NONE
# Detector ID=16, Name=T7s, Type=NONE
# Detector ID=17, Name=T7b, Type=NONE
# Detector ID=18, Name=T8s, Type=NONE
# Detector ID=19, Name=T8b, Type=NONE
# Detector ID=20, Name=T9b, Type=NONE
# Detector ID=21, Name=T10b, Type=NONE
# Detector ID=22, Name=PA, Type=NONE
# Detector ID=23, Name=PB, Type=NONE
# Detector ID=24, Name=PC, Type=NONE
# Detector ID=25, Name=GB, Type=NONE
# Detector ID=26, Name=FR, Type=NONE
# Detector ID=27, Name=SY1, Type=NONE
#
# ### Intersection Name: LD-LSA4
# Full name: LD-LSA4 (Maximilianstr./Omnibusbf.)
# Detector ID=1, Name=DET1_2, Type=NONE
# Detector ID=2, Name=DET2_2, Type=NONE
# Detector ID=3, Name=DET2_4, Type=NONE
# Detector ID=4, Name=DET3_1, Type=NONE
# Detector ID=5, Name=DET3_2, Type=NONE
# Detector ID=6, Name=TAS1, Type=NONE
# Detector ID=7, Name=BTAS1, Type=NONE
#
# === INTERSECTIONS IN CORRIDOR ===
# LD-LSA1, LD-LSA10, LD-LSA11, LD-LSA16, LD-LSA24, LD-LSA29, LD-LSA3, LD-LSA32, LD-LSA4, LD-LSA40, LD-LSA42, LD-LSA5, LD-LSA8

# %% [markdown]
# **State Control for all intersection in SUMO**

# %%
import os
import json

folder = r"C:\Users\mogul\OneDrive\Masaüstü\mt_emre\chapter 4 - build digital twin\LSTM - detector prediction\input\intersections"

def find_json_files(directory):
    files = []
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        if os.path.isfile(filepath) and filename.lower().endswith(".json"):
            files.append(filepath)
    return files

json_files = find_json_files(folder)

important_intersections = {
    "LD-LSA16", "LD-LSA10", "LD-LSA8", "LD-LSA24", "LD-LSA29", "LD-LSA32",
    "LD-LSA3", "LD-LSA11", "LD-LSA5", "LD-LSA4", "LD-LSA40", "LD-LSA42", "LD-LSA1"
}

def state_check(tlc: dict):
    reasons = []

    # active?
    if tlc.get("active") is False:
        reasons.append("active=False")

    # state?
    state = tlc.get("state")
    if state is not None and state != "NO_FAILURE":
        reasons.append(f"state={state}")

    # broken detectors?
    broken = tlc.get("brokenDetectorCount")
    if isinstance(broken, int) and broken > 0:
        reasons.append(f"brokenDetectorCount={broken}")

    # hardwareStatus checks
    hw = tlc.get("hardwareStatus", {})
    if isinstance(hw, dict):
        if hw.get("powerOk") is False:
            reasons.append("powerOk=False")
        if hw.get("emergencyOff") is True:
            reasons.append("emergencyOff=True")
        if hw.get("doorOpen") is True:
            reasons.append("doorOpen=True")
        if hw.get("persistenceOk") is False:
            reasons.append("persistenceOk=False")

    # readDetectors?
    if tlc.get("readDetectors") is False:
        reasons.append("readDetectors=False")

    ok = (len(reasons) == 0)
    return ok, reasons


found = []
ok_list = []
not_ok_list = []

for file in json_files:
    with open(file, "r", encoding="utf-8") as f:
        j = json.load(f)

    tlc = j.get("tlc", {})
    alias = tlc.get("alias", "")

    if alias not in important_intersections:
        continue

    found.append(alias)

    ok, reasons = state_check(tlc)

    if ok:
        ok_list.append(alias)
    else:
        not_ok_list.append((alias, reasons))

# --- PRINT RESULTS ---
print("=== STATE CHECK RESULTS (Corridor Intersections) ===")
print("Total found:", len(found))
print("OK:", len(ok_list))
print("NOT OK:", len(not_ok_list))

print("\nOK intersections:")
print(", ".join(sorted(ok_list)) if ok_list else "-")

print("\nNOT OK intersections (with reasons):")
if not not_ok_list:
    print("-")
else:
    for alias, reasons in sorted(not_ok_list, key=lambda x: x[0]):
        print(f"- {alias}: " + "; ".join(reasons))

print("\n=== ALL CORRIDOR INTERSECTIONS (one line) ===")
print(", ".join(sorted(set(found))))
# Out:
# === STATE CHECK RESULTS (Corridor Intersections) ===
# Total found: 13
# OK: 6
# NOT OK: 7
#
# OK intersections:
# LD-LSA10, LD-LSA11, LD-LSA24, LD-LSA29, LD-LSA32, LD-LSA42
#
# NOT OK intersections (with reasons):
# - LD-LSA1: state=INTERNAL_FAILURE; brokenDetectorCount=2
# - LD-LSA16: state=DETECTOR_FAILURE; brokenDetectorCount=2
# - LD-LSA3: readDetectors=False
# - LD-LSA4: state=INTERNAL_FAILURE; brokenDetectorCount=2
# - LD-LSA40: state=CONNECTION_ERROR
# - LD-LSA5: state=INTERNAL_FAILURE; brokenDetectorCount=2
# - LD-LSA8: state=ERROR; persistenceOk=False
#
# === ALL CORRIDOR INTERSECTIONS (one line) ===
# LD-LSA1, LD-LSA10, LD-LSA11, LD-LSA16, LD-LSA24, LD-LSA29, LD-LSA3, LD-LSA32, LD-LSA4, LD-LSA40, LD-LSA42, LD-LSA5, LD-LSA8

# %% [markdown]
# *Which dedectors have failure?**

# %%
import json

print("=== FAULT DETECTORS (Corridor) ===")

for file in json_files:
    with open(file, "r", encoding="utf-8") as f:
        j = json.load(f)

    tlc = j.get("tlc", {})
    alias = tlc.get("alias", "")

    if alias not in important_intersections:
        continue

    hw = tlc.get("hardwareStatus", {})
    faults = hw.get("faultDetectors", []) if isinstance(hw, dict) else []

    if faults:
        names = [d.get("name") for d in faults if isinstance(d, dict)]
        print(f"- {alias}: {', '.join([n for n in names if n])}")
    else:
        print(f"- {alias}: (no faultDetectors listed)")
# Out:
# === FAULT DETECTORS (Corridor) ===
# - LD-LSA29: (no faultDetectors listed)
# - LD-LSA3: (no faultDetectors listed)
# - LD-LSA5: WBK2_Err, WBK1_Err
# - LD-LSA16: WD41, WD42
# - LD-LSA10: (no faultDetectors listed)
# - LD-LSA42: (no faultDetectors listed)
# - LD-LSA40: (no faultDetectors listed)
# - LD-LSA11: (no faultDetectors listed)
# - LD-LSA24: (no faultDetectors listed)
# - LD-LSA32: (no faultDetectors listed)
# - LD-LSA1: DET72, DET51
# - LD-LSA8: (no faultDetectors listed)
# - LD-LSA4: DET2_2, DET2_4

# %% [markdown]
# **For LSTM Training**

# %%
import json

def state_check_and_faults(tlc: dict):
    reasons = []

    # state check
    if tlc.get("active") is False:
        reasons.append("active=False")

    state = tlc.get("state")
    if state is not None and state != "NO_FAILURE":
        reasons.append(f"state={state}")

    broken = tlc.get("brokenDetectorCount")
    if isinstance(broken, int) and broken > 0:
        reasons.append(f"brokenDetectorCount={broken}")

    hw = tlc.get("hardwareStatus", {})
    if isinstance(hw, dict):
        if hw.get("powerOk") is False:
            reasons.append("powerOk=False")
        if hw.get("emergencyOff") is True:
            reasons.append("emergencyOff=True")
        if hw.get("doorOpen") is True:
            reasons.append("doorOpen=True")
        if hw.get("persistenceOk") is False:
            reasons.append("persistenceOk=False")

        fault_list = hw.get("faultDetectors", [])
    else:
        fault_list = []

    fault_names = [
        d.get("name") for d in fault_list
        if isinstance(d, dict) and d.get("name")
    ]

    ok = (len(reasons) == 0)
    return ok, reasons, fault_names


# --- Build notes for each corridor intersection ---
notes = []

for file in json_files:
    with open(file, "r", encoding="utf-8") as f:
        j = json.load(f)

    tlc = j.get("tlc", {})
    alias = tlc.get("alias", "")

    if alias not in important_intersections:
        continue

    ok, reasons, fault_names = state_check_and_faults(tlc)

    # Decision logic (clear and defensible for a thesis)
    decision = "USE for LSTM training" if ok else "DO NOT use for LSTM training"

    cleaning_note = (
        "No detector cleaning required"
        if not fault_names
        else "Mask / remove faulty detectors: " + ", ".join(fault_names)
    )

    reason_note = (
        "Reason: operational state is normal (NO_FAILURE, no broken detectors)"
        if ok
        else "Reason: " + "; ".join(reasons)
    )

    notes.append((alias, decision, cleaning_note, reason_note))


# --- Print final notes (one by one) ---
print("=== INTERSECTION USABILITY NOTES FOR LSTM ===\n")

for alias, decision, cleaning_note, reason_note in sorted(notes, key=lambda x: x[0]):
    print(f"- {alias}: {decision}")
    print(f"  {cleaning_note}")
    print(f"  {reason_note}\n")
# Out:
# === INTERSECTION USABILITY NOTES FOR LSTM ===
#
# - LD-LSA1: DO NOT use for LSTM training
#   Mask / remove faulty detectors: DET72, DET51
#   Reason: state=INTERNAL_FAILURE; brokenDetectorCount=2
#
# - LD-LSA10: USE for LSTM training
#   No detector cleaning required
#   Reason: operational state is normal (NO_FAILURE, no broken detectors)
#
# - LD-LSA11: USE for LSTM training
#   No detector cleaning required
#   Reason: operational state is normal (NO_FAILURE, no broken detectors)
#
# - LD-LSA16: DO NOT use for LSTM training
#   Mask / remove faulty detectors: WD41, WD42
#   Reason: state=DETECTOR_FAILURE; brokenDetectorCount=2
#
# - LD-LSA24: USE for LSTM training
#   No detector cleaning required
#   Reason: operational state is normal (NO_FAILURE, no broken detectors)
#
# - LD-LSA29: USE for LSTM training
#   No detector cleaning required
#   Reason: operational state is normal (NO_FAILURE, no broken detectors)
#
# - LD-LSA3: USE for LSTM training
#   No detector cleaning required
#   Reason: operational state is normal (NO_FAILURE, no broken detectors)
#
# - LD-LSA32: USE for LSTM training
#   No detector cleaning required
#   Reason: operational state is normal (NO_FAILURE, no broken detectors)
#
# - LD-LSA4: DO NOT use for LSTM training
#   Mask / remove faulty detectors: DET2_2, DET2_4
#   Reason: state=INTERNAL_FAILURE; brokenDetectorCount=2
#
# - LD-LSA40: DO NOT use for LSTM training
#   No detector cleaning required
#   Reason: state=CONNECTION_ERROR
#
# - LD-LSA42: USE for LSTM training
#   No detector cleaning required
#   Reason: operational state is normal (NO_FAILURE, no broken detectors)
#
# - LD-LSA5: DO NOT use for LSTM training
#   Mask / remove faulty detectors: WBK2_Err, WBK1_Err
#   Reason: state=INTERNAL_FAILURE; brokenDetectorCount=2
#
# - LD-LSA8: DO NOT use for LSTM training
#   No detector cleaning required
#   Reason: state=ERROR; persistenceOk=False

# %%
# Only physical vehicle detectors (DET) are going to be used???
# as inputs to the LSTM model.
# Internal controller signals, timers,
# bus priority triggers, and fault indicators
# (e.g., T*, BT*, VK*, FE*)
# are going to excluded???, as they do not represent
# traffic flow measurements.???
