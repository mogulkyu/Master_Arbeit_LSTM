# %% [markdown]
# **Load simulation**

# %%
import sys
# !{sys.executable} -m pip install torch torchvision torchaudio
# Out:
# ...
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#     --------------------------------------- 2.4/113.8 MB 12.4 MB/s eta 0:00:09
#    - -------------------------------------- 5.0/113.8 MB 12.1 MB/s eta 0:00:09
#    -- ------------------------------------- 7.3/113.8 MB 11.7 MB/s eta 0:00:10
#    --- ------------------------------------ 10.0/113.8 MB 12.0 MB/s eta 0:00:09
#    ---- ----------------------------------- 12.3/113.8 MB 12.0 MB/s eta 0:00:09
#    ----- ---------------------------------- 15.2/113.8 MB 12.1 MB/s eta 0:00:09
#    ------ --------------------------------- 17.8/113.8 MB 12.2 MB/s eta 0:00:08
#    ------- -------------------------------- 20.2/113.8 MB 12.2 MB/s eta 0:00:08
#    ------- -------------------------------- 21.5/113.8 MB 11.4 MB/s eta 0:00:09
#    -------- ------------------------------- 23.6/113.8 MB 11.4 MB/s eta 0:00:08
#    --------- ------------------------------ 26.2/113.8 MB 11.4 MB/s eta 0:00:08
# ...
